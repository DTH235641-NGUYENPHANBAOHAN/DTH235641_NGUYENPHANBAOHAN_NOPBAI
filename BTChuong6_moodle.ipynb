# %%
#Câu 1
lst = []

n = int(input("Nhập số lượng phần tử muốn thêm: "))
for i in range(n):
    x = int(input(f"Nhập phần tử thứ {i+1}: "))
    lst.append(x)

print("\nDanh sách vừa nhập:", lst)

k = int(input("\nNhập giá trị k cần kiểm tra: "))
count_k = lst.count(k)
print(f"Giá trị {k} xuất hiện {count_k} lần trong list.")

def la_so_nguyen_to(x):
    if x < 2:
        return False
    for i in range(2, int(x**0.5) + 1):
        if x % i == 0:
            return False
    return True

tong_nt = sum(x for x in lst if la_so_nguyen_to(x))
print("Tổng các số nguyên tố trong list là:", tong_nt)

lst.sort()
print("List sau khi sắp xếp tăng dần:", lst)

lst.clear()
print("List sau khi xóa:", lst)
# Out:
# Nhập số lượng phần tử muốn thêm: 3
# Nhập phần tử thứ 1: 0
# Nhập phần tử thứ 2: 5
# Nhập phần tử thứ 3: 2
#
# Danh sách vừa nhập: [0, 5, 2]
#
# Nhập giá trị k cần kiểm tra: 5
# Giá trị 5 xuất hiện 1 lần trong list.
# Tổng các số nguyên tố trong list là: 7
# List sau khi sắp xếp tăng dần: [0, 2, 5]
# List sau khi xóa: []

# %%
#Câu 2
import random

n = int(input("Nhập số phần tử của list: "))
lst = [random.randint(0, 100) for _ in range(n)]  # sinh ngẫu nhiên từ 0 đến 100
print("List ban đầu:", lst)

k = int(input("\nNhập giá trị k cần xóa: "))
lst = [x for x in lst if x != k]
print("List sau khi xóa tất cả phần tử có giá trị", k, ":", lst)

if lst == lst[::-1]:
    print("List là đối xứng.")
else:
    print("List không đối xứng.")
# Out:
# Nhập số phần tử của list: 3
# List ban đầu: [9, 87, 30]
#
# Nhập giá trị k cần xóa: 9
# List sau khi xóa tất cả phần tử có giá trị 9 : [87, 30]
# List không đối xứng.

# %%
#Câu 3
import random

m = int(input("Nhập số dòng (m): "))
n = int(input("Nhập số cột (n): "))

matrix = [[random.randint(0, 100) for j in range(n)] for i in range(m)]

print("\nMa trận ngẫu nhiên:")
for row in matrix:
    print(row)

dong = int(input("\nNhập số dòng muốn xuất (tính từ 0): "))
if 0 <= dong < m:
    print(f"Dòng {dong}: {matrix[dong]}")
else:
    print("Dòng không hợp lệ!")

cot = int(input("\nNhập số cột muốn xuất (tính từ 0): "))
if 0 <= cot < n:
    cot_data = [matrix[i][cot] for i in range(m)]
    print(f"Cột {cot}: {cot_data}")
else:
    print("Cột không hợp lệ!")

max_value = max(max(row) for row in matrix)
print("\nGiá trị lớn nhất trong ma trận là:", max_value)
# Out:
# Nhập số dòng (m): 2
# Nhập số cột (n): 3
#
# Ma trận ngẫu nhiên:
# [25, 78, 49]
# [55, 61, 18]
#
# Nhập số dòng muốn xuất (tính từ 0): 1
# Dòng 1: [55, 61, 18]
#
# Nhập số cột muốn xuất (tính từ 0): 3
# Cột không hợp lệ!
#
# Giá trị lớn nhất trong ma trận là: 78

# %%
#Câu 4
a) 3
b) 5
c) 1
d) 5
e) 5
f) 2
g) 0
h) 3

# %%
#Câu 5
(a) [20, 1, -34, 40, -8, 60, 1, 3]
(b) [20, 1, -34]
(c) [-8, 60, 1, 3]
(d) [-8, 60, 1, 3]
(e) [40, -8]
(f) [20, 1, -34]
(g) [-8, 60, 1, 3]
(h) [20, 1, -34, 40, -8, 60, 1, 3]
(i) [20, 1, -34, 40]
(j) [1, -34, 40, -8]
(k) True
(l) False
(m) 8

# %%
#Câu 6
def nhap_matrix(rows, cols, name="Matrix"):
    print(f"Nhập các phần tử cho {name}:")
    matrix = []
    for i in range(rows):
        row = list(map(float, input(f"Hàng {i+1}: ").split()))
        while len(row) != cols:
            print(f"Vui lòng nhập đúng {cols} phần tử.")
            row = list(map(float, input(f"Hàng {i+1}: ").split()))
        matrix.append(row)
    return matrix

def cong_matrix(A, B):
    rows, cols = len(A), len(A[0])
    result = [[A[i][j] + B[i][j] for j in range(cols)] for i in range(rows)]
    return result

def transpose_matrix(M):
    rows, cols = len(M), len(M[0])
    transposed = [[M[j][i] for j in range(rows)] for i in range(cols)]
    return transposed

def in_matrix(M, name="Matrix"):
    print(f"\n{name}:")
    for row in M:
        print(" ".join(map(str, row)))

# --- Chương trình chính ---
if __name__ == "__main__":
    r = int(input("Nhập số hàng: "))
    c = int(input("Nhập số cột: "))

    A = nhap_matrix(r, c, "Matrix A")
    B = nhap_matrix(r, c, "Matrix B")

    # Xuất ma trận A, B
    in_matrix(A, "Matrix A")
    in_matrix(B, "Matrix B")

    # Cộng A + B
    C = cong_matrix(A, B)
    in_matrix(C, "A + B")

    # Hoán vị A và B
    At = transpose_matrix(A)
    Bt = transpose_matrix(B)
    in_matrix(At, "Transpose(A)")
    in_matrix(Bt, "Transpose(B)")
# Out:
# Nhập số hàng: 2
# Nhập số cột: 3
# Nhập các phần tử cho Matrix A:
# Hàng 1: 3 7 1
# Hàng 2: 4 9 0
# Nhập các phần tử cho Matrix B:
# Hàng 1: 8 5 3
# Hàng 2: 1 7 4
#
# Matrix A:
# 3.0 7.0 1.0
# 4.0 9.0 0.0
#
# Matrix B:
# 8.0 5.0 3.0
# 1.0 7.0 4.0
#
# A + B:
# 11.0 12.0 4.0
# 5.0 16.0 4.0
#
# Transpose(A):
# 3.0 4.0
# 7.0 9.0
# 1.0 0.0
#
# Transpose(B):
# 8.0 1.0
# 5.0 7.0
# 3.0 4.0

# %%
#Câu 7
def nhap_matrix(rows, cols, name="Matrix"):
    print(f"Nhập các phần tử cho {name}:")
    matrix = []
    for i in range(rows):
        row = list(map(float, input(f"Hàng {i+1}: ").split()))
        while len(row) != cols:
            print(f"Vui lòng nhập đúng {cols} phần tử.")
            row = list(map(float, input(f"Hàng {i+1}: ").split()))
        matrix.append(row)
    return matrix

def cong_matrix(A, B):
    rows, cols = len(A), len(A[0])
    result = [[A[i][j] + B[i][j] for j in range(cols)] for i in range(rows)]
    return result

def transpose_matrix(M):
    rows, cols = len(M), len(M[0])
    transposed = [[M[j][i] for j in range(rows)] for i in range(cols)]
    return transposed

def in_matrix(M, name="Matrix"):
    print(f"\n{name}:")
    for row in M:
        print(" ".join(map(str, row)))

# --- Chương trình chính ---
if __name__ == "__main__":
    r = int(input("Nhập số hàng: "))
    c = int(input("Nhập số cột: "))

    A = nhap_matrix(r, c, "Matrix A")
    B = nhap_matrix(r, c, "Matrix B")

    # Xuất ma trận A, B
    in_matrix(A, "Matrix A")
    in_matrix(B, "Matrix B")

    # Cộng A + B
    C = cong_matrix(A, B)
    in_matrix(C, "A + B")

    # Hoán vị A và B
    At = transpose_matrix(A)
    Bt = transpose_matrix(B)
    in_matrix(At, "Transpose(A)")
    in_matrix(Bt, "Transpose(B)")
# Out:
# Nhập số hàng: 2
# Nhập số cột: 3
# Nhập các phần tử cho Matrix A:
# Hàng 1: 7 2 0
# Hàng 2: 3 6 1
# Nhập các phần tử cho Matrix B:
# Hàng 1: 4 9 5
# Hàng 2: 7 1 8
#
# Matrix A:
# 7.0 2.0 0.0
# 3.0 6.0 1.0
#
# Matrix B:
# 4.0 9.0 5.0
# 7.0 1.0 8.0
#
# A + B:
# 11.0 11.0 5.0
# 10.0 7.0 9.0
#
# Transpose(A):
# 7.0 3.0
# 2.0 6.0
# 0.0 1.0
#
# Transpose(B):
# 4.0 7.0
# 9.0 1.0
# 5.0 8.0

# %%
#Câu 8
def nhap_matrix(rows, cols, name="Matrix"):
    print(f"Nhập các phần tử cho {name}:")
    matrix = []
    for i in range(rows):
        row = list(map(float, input(f"Hàng {i+1}: ").split()))
        while len(row) != cols:
            print(f"Vui lòng nhập đúng {cols} phần tử.")
            row = list(map(float, input(f"Hàng {i+1}: ").split()))
        matrix.append(row)
    return matrix

def cong_matrix(A, B):
    rows, cols = len(A), len(A[0])
    result = [[A[i][j] + B[i][j] for j in range(cols)] for i in range(rows)]
    return result

def transpose_matrix(M):
    rows, cols = len(M), len(M[0])
    transposed = [[M[j][i] for j in range(rows)] for i in range(cols)]
    return transposed

def in_matrix(M, name="Matrix"):
    print(f"\n{name}:")
    for row in M:
        print(" ".join(map(str, row)))

# --- Chương trình chính ---
if __name__ == "__main__":
    r = int(input("Nhập số hàng: "))
    c = int(input("Nhập số cột: "))

    A = nhap_matrix(r, c, "Matrix A")
    B = nhap_matrix(r, c, "Matrix B")

    # Xuất ma trận A, B
    in_matrix(A, "Matrix A")
    in_matrix(B, "Matrix B")

    # Cộng A + B
    C = cong_matrix(A, B)
    in_matrix(C, "A + B")

    # Hoán vị A và B
    At = transpose_matrix(A)
    Bt = transpose_matrix(B)
    in_matrix(At, "Transpose(A)")
    in_matrix(Bt, "Transpose(B)")
# Out:
# Nhập số hàng: 2
# Nhập số cột: 3
# Nhập các phần tử cho Matrix A:
# Hàng 1: 5 2 6
# Hàng 2: 7 4 3
# Nhập các phần tử cho Matrix B:
# Hàng 1: 6 8 0
# Hàng 2: 1 9 7
#
# Matrix A:
# 5.0 2.0 6.0
# 7.0 4.0 3.0
#
# Matrix B:
# 6.0 8.0 0.0
# 1.0 9.0 7.0
#
# A + B:
# 11.0 10.0 6.0
# 8.0 13.0 10.0
#
# Transpose(A):
# 5.0 7.0
# 2.0 4.0
# 6.0 3.0
#
# Transpose(B):
# 6.0 1.0
# 8.0 9.0
# 0.0 7.0

# %%
#Câu 9
def nhap_matrix(rows, cols, name="Matrix"):
    print(f"Nhập các phần tử cho {name}:")
    matrix = []
    for i in range(rows):
        row = list(map(float, input(f"Hàng {i+1}: ").split()))
        while len(row) != cols:
            print(f"Vui lòng nhập đúng {cols} phần tử.")
            row = list(map(float, input(f"Hàng {i+1}: ").split()))
        matrix.append(row)
    return matrix

def cong_matrix(A, B):
    rows, cols = len(A), len(A[0])
    result = [[A[i][j] + B[i][j] for j in range(cols)] for i in range(rows)]
    return result

def transpose_matrix(M):
    rows, cols = len(M), len(M[0])
    transposed = [[M[j][i] for j in range(rows)] for i in range(cols)]
    return transposed

def in_matrix(M, name="Matrix"):
    print(f"\n{name}:")
    for row in M:
        print(" ".join(map(str, row)))

# --- Chương trình chính ---
if __name__ == "__main__":
    r = int(input("Nhập số hàng: "))
    c = int(input("Nhập số cột: "))

    A = nhap_matrix(r, c, "Matrix A")
    B = nhap_matrix(r, c, "Matrix B")

    # Xuất ma trận A, B
    in_matrix(A, "Matrix A")
    in_matrix(B, "Matrix B")

    # Cộng A + B
    C = cong_matrix(A, B)
    in_matrix(C, "A + B")

    # Hoán vị A và B
    At = transpose_matrix(A)
    Bt = transpose_matrix(B)
    in_matrix(At, "Transpose(A)")
    in_matrix(Bt, "Transpose(B)")
# Out:
# Nhập số hàng: 2
# Nhập số cột: 3
# Nhập các phần tử cho Matrix A:
# Hàng 1: 7 5 2
# Hàng 2: 6 1 5
# Nhập các phần tử cho Matrix B:
# Hàng 1: 9 3 1
# Hàng 2: 4 8 0
#
# Matrix A:
# 7.0 5.0 2.0
# 6.0 1.0 5.0
#
# Matrix B:
# 9.0 3.0 1.0
# 4.0 8.0 0.0
#
# A + B:
# 16.0 8.0 3.0
# 10.0 9.0 5.0
#
# Transpose(A):
# 7.0 6.0
# 5.0 1.0
# 2.0 5.0
#
# Transpose(B):
# 9.0 4.0
# 3.0 8.0
# 1.0 0.0

# %%
#Câu 10
def nhap_matrix(rows, cols, name="Matrix"):
    print(f"Nhập các phần tử cho {name}:")
    matrix = []
    for i in range(rows):
        row = list(map(float, input(f"Hàng {i+1}: ").split()))
        while len(row) != cols:
            print(f"Vui lòng nhập đúng {cols} phần tử.")
            row = list(map(float, input(f"Hàng {i+1}: ").split()))
        matrix.append(row)
    return matrix

def cong_matrix(A, B):
    rows, cols = len(A), len(A[0])
    result = [[A[i][j] + B[i][j] for j in range(cols)] for i in range(rows)]
    return result

def transpose_matrix(M):
    rows, cols = len(M), len(M[0])
    transposed = [[M[j][i] for j in range(rows)] for i in range(cols)]
    return transposed

def in_matrix(M, name="Matrix"):
    print(f"\n{name}:")
    for row in M:
        print(" ".join(map(str, row)))

# --- Chương trình chính ---
if __name__ == "__main__":
    r = int(input("Nhập số hàng: "))
    c = int(input("Nhập số cột: "))

    A = nhap_matrix(r, c, "Matrix A")
    B = nhap_matrix(r, c, "Matrix B")

    # Xuất ma trận A, B
    in_matrix(A, "Matrix A")
    in_matrix(B, "Matrix B")

    # Cộng A + B
    C = cong_matrix(A, B)
    in_matrix(C, "A + B")

    # Hoán vị A và B
    At = transpose_matrix(A)
    Bt = transpose_matrix(B)
    in_matrix(At, "Transpose(A)")
    in_matrix(Bt, "Transpose(B)")
# Out:
# Nhập số hàng: 2
# Nhập số cột: 3
# Nhập các phần tử cho Matrix A:
# Hàng 1: 3 1 9
# Hàng 2: 7 6 2
# Nhập các phần tử cho Matrix B:
# Hàng 1: 8 1 9
# Hàng 2: 0 7 5
#
# Matrix A:
# 3.0 1.0 9.0
# 7.0 6.0 2.0
#
# Matrix B:
# 8.0 1.0 9.0
# 0.0 7.0 5.0
#
# A + B:
# 11.0 2.0 18.0
# 7.0 13.0 7.0
#
# Transpose(A):
# 3.0 7.0
# 1.0 6.0
# 9.0 2.0
#
# Transpose(B):
# 8.0 0.0
# 1.0 7.0
# 9.0 5.0
