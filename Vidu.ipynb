# %%
print("Chào các bạn!")
# Out:
# Chào các bạn!

# %%
print("Albert Einstein đã từng nói: Một ngươi không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.")
# Out:
# Albert Einstein đã từng nói: Một ngươi không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.
